# %% [markdown]
# **Навигация по уроку**
#
# 1. [Введение в Python. Синтаксис](https://colab.research.google.com/drive/1YBLgd6tZYlkhwpnEc4IM8tVnewLUnlUO#scrollTo=yqZjRAldfz_L)
# 2. [Практика](https://colab.research.google.com/drive/1m-Ph90c-9S_gZchdG1ARoY2YjMTryKkl#scrollTo=UdxWiGmA63K2)
# 3. Домашняя работа

# %% [markdown]
# В домашней работе необходимо, используя знания теоретической части занятия и полученные практические навыки, решить, представленные ниже задачи. Для этого необходимо скопировать Блокнот (см. раздел 1.1.), решить в нем все задач, открыть общий доступ к Блокноту ((см. раздел 1.1.) и отправить ссылку на Блокнот куратору на проверку. Желаем удачи!

# %% [markdown]
# ## Задача 1. Приветствие.

# %% [markdown]
# **Условие.** Напишите программу, запрашивающую у пользователя его имя. В ответ
# на ввод на экране должно появиться приветствие с обращением по имени,
# введенному с клавиатуры ранее.

# %%
# Решение
#
name = input("Введите Ваше имя: ")
print("Здравствуйте,", name,"!")
# Out:
# Введите Ваше имя: Илья
# Здравствуйте, Илья !

# %% [markdown]
# ## Задача 2. Сувениры и безделушки.

# %% [markdown]
# **Условие.** Интернет-магазин занимается продажей различных сувениров и безделушек. Каждый сувенир весит 75 г, а безделушка – 112 г. Напишите программу, запрашивающую у пользователя количество тех и других покупок,
# после чего выведите на экран общий вес посылки.

# %%
# Решение
#
# определяем вес сувенира и безделушки
souvenirweight = 75
trinketweight = 112
#Запрашиваем количество у пользователя и проверяем числовые значения
while True:
    try:
        souvenirquantity = int(input("Введите количество сувениров "))
        trinketquantity = int(input("Введите количество безделушек "))
        break
    except ValueError:
        print("Допустимы только числовые значения. ")
# считаем общий вес покупок
totalweight = souvenirweight * souvenirquantity + trinketweight * trinketquantity
# Выводим общий вес посылки
print("Общий вес посылки составит:", totalweight)
# Out:
# Введите количество сувениров пять
# Допустимы только числовые значения.
# Введите количество сувениров 5
# Введите количество безделушек 10
# Общий вес посылки составит: 1495

# %% [markdown]
# ## Задача 3. Сложные проценты

# %% [markdown]
# **Условие.** Представьте, что вы открыли в банке сберегательный счет под 4 % годовых. Проценты банк рассчитывает в конце года и добавляет к сумме счета.
# Напишите программу, которая запрашивает у пользователя сумму первоначального депозита, после чего рассчитывает и выводит на экран сумму
# на счету в конце первого, второго и третьего годов. Все суммы должны
# быть округлены до двух знаков после запятой.

# %%
# Решение
#
# Вычисляем процент
ppa = 0.04
# Запрашиваем сумму у пользователя
deposit = float(input("Введите сумму депозита "))
# Проводим расчёты по каждому году
value1year = deposit * ppa + deposit
value2year = value1year * ppa + value1year
value3year = value2year * ppa + value2year
# Выводим на экран суммы на счету
print("Сумма на счету за: " "Первый год: %.2f. " "Второй год: %.2f. " "Третий год: %.2f." % ( value1year, value2year, value3year ))
# Out:
# Введите сумму депозита 7500
# Сумма на счету за: Первый год: 7800.00. Второй год: 8112.00. Третий год: 8436.48.

# %% [markdown]
# ## Задача 4. Арифметика

# %% [markdown]
# **Условие.** Создайте программу, которая запрашивает у пользователя два целых числа a и b, после чего выводит на экран результаты следующих математических операций:
# * сумма a и b;
# * разница между a и b;
# * произведение a и b;
# * частное от деления a на b;
# * остаток от деления a на b;
# * десятичный логарифм числа a;
# * результат возведения числа a в степень b.

# %%
#Решение
#
import math
# Запрашиваем значение чисел у пользователя
while True:
    try:
        a = int(input("Введите целое число a: "))
        b = int(input("Введите целое число b: "))
        a / b
        if a <=0:
          raise ValueError()
        break
    except ZeroDivisionError:
        print("Деление на ноль")
    except ValueError:
        print("Допустимы только целые числа при значении a больше нуля. ")
# Выполняем вычисления и выводим на экран
print("a + b = ", a + b)
print("a - b = ", a - b)
print("a * b = ", a * b)
print("a / b = ", a / b)
print("a % b = ", a % b)
print("log10(a) = ", math.log10(a))
print("a ** b = ", a ** b)
# Out:
# Введите целое число a: 0
# Введите целое число b: 7
# Допустимы только целые числа при значении a больше нуля.
# Введите целое число a: 7
# Введите целое число b: 5
# a + b =  12
# a - b =  2
# a * b =  35
# a / b =  1.4
# a % b =  2
# log10(a) =  0.8450980400142568
# a ** b =  16807

# %% [markdown]
# ## Задача 5. Размен

# %% [markdown]
# **Условие.** Представьте, что вы пишете программное обеспечение для автоматической кассы в  магазине самообслуживания. Одной из функций, заложенных в кассу, должен быть расчет сдачи в случае оплаты покупателем наличными.
# Напишите программу, которая будет запрашивать у пользователя сумму сдачи в копейках. После этого она должна рассчитать и вывести на экран, сколько и каких монет потребуется для выдачи указанной суммы, при условии что должно быть задействовано минимально возможное количество монет. Допустим, у нас есть в распоряжении монеты достоинством в 1, 5, 10, 50 копеек, а также в 1, 2 и 5 рублей.

# %%
#Решение
#
# Считаем номиналы монет
kp1 = 1
kp5 = 5
kp10 = 10
kp50 = 50
rbl1 = 100
rbl2 = 200
rbl5 = 500
# Запрос данных от пользователя и проверка ввода
while True:
    try:
        change = int(input("Введите количество сдачи в копейках: "))
        break
    except ValueError:
        print("Допустимы только числовые значения. ")
# Считаем сдачу, используя номиналы монет, целочисленное деление и деление, получая остаток от деления. Выводим на экран.
print("Количество ", change // rbl5, "Монеты 5 рублей")
change = change % rbl5
print("Количество ", change // rbl2, "Монеты 2 рубля")
change = change % rbl2
print("Количество ", change // rbl1, "Монеты 1 рубль")
change = change % rbl1
print("Количество ", change // kp50, "Монеты 50 копеек")
change = change % kp50
print("Количество ", change // kp10, "Монеты 10 копеек")
change = change % kp10
print("Количество ", change // kp5, "Монеты 5 копеек")
change = change % kp5
print("Количество ", change // kp1, "Монеты 1 копейка")
change = change % kp1
# Out:
# Введите количество сдачи в копейках: 1237
# Количество  2 Монеты 5 рублей
# Количество  1 Монеты 2 рубля
# Количество  0 Монеты 1 рубль
# Количество  0 Монеты 50 копеек
# Количество  3 Монеты 10 копеек
# Количество  1 Монеты 5 копеек
# Количество  2 Монеты 1 копейка

# %% [markdown]
# ## Задача 6. Вчерашний хлеб

# %% [markdown]
# **Условие.** Пекарня продает хлеб по 49 рублей за буханку. Скидка на вчерашний хлеб составляет 60 %. Напишите программу, которая будет запрашивать у пользователя количество приобретенных вчерашних буханок хлеба. В вывод на экран должны быть включены обычная цена за буханку, цена со скидкой и общая стоимость приобретенного хлеба. Все значения должны быть выведены на отдельных строках с соответствующими описаниями. Используйте для вывода формат с двумя знаками после запятой и 5-ю знакоместами.

# %%
#Решение
#
# Определяем цену хлеба и скидку
breadprice = 49
discount = 0.60
# Запрашиваем у пользователя количество купленных вчерашних буханок хлеба
yesterbread = int(input("Введите количество приобритённых вчерашних буханок хлеба: "))
# Считаем цены и выводим на экран
standartprice = yesterbread * breadprice
discountprice = standartprice * discount
totalprice = standartprice - discountprice
print("Цена без скидки: %5.2f" % standartprice)
print("Цена со скидкой: %5.2f" % discountprice)
print("Скидка: %5.2f" % totalprice)
# Out:
# Введите количество приобритённых вчерашних буханок хлеба: 7
# Цена без скидки: 343.00
# Цена со скидкой: 205.80
# Скидка: 137.20
